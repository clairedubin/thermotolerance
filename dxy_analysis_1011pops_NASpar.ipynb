# %%
import pandas as pd
import numpy as np
import csv

# %%
#essential genes + GO term info
essential = pd.read_csv('/Users/clairedubin/sacc/external_datasets/essential.csv', header=None)
essential[1] = essential[1].str.strip('\t')
essential_genes = essential[1].str.strip(' ').tolist()

#load go term data as go_terms, remove 3 broad go terms
#source: http://geneontology.org/docs/download-go-annotations/
go_terms = pd.read_csv('/Users/clairedubin/sacc/external_datasets/go_terms.csv', header=None)
go_terms = go_terms.drop(columns=[0, 1,3,5,6,7,8,11,12,13,14,15])
go_terms = go_terms.rename(columns={2: 'sgd_name', 4:'go_term', 9:'gene_desc', 10:'gene'})
go_terms['gene'] = [i[0] for i in go_terms['gene'].str.split('|')]
go_terms = go_terms.drop_duplicates()
go_terms = go_terms[~go_terms['go_term'].isin(['GO:0005575', 'GO:0008150', 'GO:0003674'])]
go_terms = go_terms.set_index('gene')

# %%
def resample(df1, df2, n=10000, graph=False):
    
    results = 0

    actual_med = df1['dxy'].median()
    
    essential_count = len([i for i in df1['gene'] if i in essential_genes])
    nonessential_count = len(df1['gene']) - essential_count
    
    print('candidate gene median dxy: ', actual_med)
    print('essential count: '+str(essential_count)+', nonessential_count: '+str(nonessential_count))
    print('resampling pool size: ', df2.shape[0])
    
    essential_df = df2[df2['gene'].isin(essential_genes)]
    nonessential_df =  df2[~df2['gene'].isin(essential_genes)]

    sample_meds = []
    
    for _ in range(n):
        sample = essential_df.sample(n=essential_count)
        sample = sample.append(nonessential_df.sample(n=nonessential_count))
        sample_med = sample['dxy'].median()
        sample_meds += [sample_med]
        if sample_med >= actual_med:
            results += 1
    
    if graph:
        
        print('p=',results/n)
        sns.distplot(sample_meds)
        plt.axvline(x=actual_med, color='r', label = 'True median')
        plt.xlabel('Sample medians')
        plt.ylabel('Frequency')
    
    return results/n

# %%
gene_dict = {'YDR180W':'SCC2',
             'YMR168C':'CEP3',
             'YCR042C': 'TAF2',
             'YGR198W':'YPP1',
             'YHR166C': 'CDC23',
             'YHR023W':'MYO1',
             'YLR397C': 'AFG2',
             'YKR054C': 'DYN1',
             'YPL174C':'NIP100',
             'YGR098C':'ESP1'                    
            }

# %%
#group Scer strains by population

pops = pd.read_csv('/Users/clairedubin/sacc/external_datasets/1011_pops_tableS1.csv', skiprows=3)
pops = pops[['Standardized name', 'Clades']].dropna()
pops['population'] = pops['Clades'].str.replace('[^\w]','')

pop_dict = pops.groupby('population')['Standardized name'].count().to_dict()
pop_dict
# Out:
# {'10FrenchGuianahuman': 31,
#  '11Alebeer': 18,
#  '12WestAfricancocoa': 13,
#  '13Africanpalmwine': 28,
#  '14CHNIII': 2,
#  '15CHNII': 2,
#  '16CHNI': 1,
#  '17Taiwanese': 3,
#  '18FarEastAsia': 9,
#  '19Malaysian': 6,
#  '1WineEuropean': 268,
#  '1WineEuropeansubclade1': 18,
#  '1WineEuropeansubclade2': 13,
#  '1WineEuropeansubclade3': 24,
#  '1WineEuropeansubclade4': 39,
#  '20CHNV': 2,
#  '21Ecuadorean': 10,
#  '22FarEastRussian': 4,
#  '23NorthAmericanoak': 13,
#  '24Asianislands': 11,
#  '25Sake': 47,
#  '26Asianfermentation': 39,
#  '2Alpechin': 17,
#  '3Brazilianbioethanol': 35,
#  '4Mediterraneanoak': 8,
#  '5Frenchdairy': 32,
#  '6Africanbeer': 20,
#  '7Mosaicbeer': 21,
#  '8Mixedorigin': 72,
#  '9Mexicanagave': 7,
#  'M1Mosaicregion1': 17,
#  'M2Mosaicregion2': 20,
#  'M3Mosaicregion3': 113}

# %%
#load raw dxy data

all_dxy = pd.read_csv('/Users/clairedubin/sacc/carly_genes/dxy_1011pops_NASpar.csv', header=None)
all_dxy.columns = ['population', 'gene', 'dxy', 'spar_strain_count', 'scer_strain_count']
all_dxy.head()
# Out:
#       population     gene       dxy  spar_strain_count  scer_strain_count
# 0    17Taiwanese  YLR457C  0.127083                 10                  3
# 1    19Malaysian  YLR457C  0.127083                 10                  6
# 2       14CHNIII  YLR457C  0.128125                 10                  2
# 3        15CHNII  YLR457C  0.126562                 10                  2
# 4  18FarEastAsia  YLR457C  0.129398                 10                  9

# %%
#drop any rows where spar_strain_count < 8 or scer_strain count < 75% of the population

all_dxy = all_dxy[all_dxy['spar_strain_count'] >= 8]

# %%
np.random.seed(777)

p_dict = {}

for pop in pop_dict:
    size = pop_dict[pop]
    
    df = all_dxy[all_dxy['population']==pop]
    df = df[df['scer_strain_count']>= .75*size]
    
    candidates = df[df['gene'].isin(gene_dict.keys())]
    
    print('')
    print('---- {} ----'.format(pop))

    print('missing: ', [gene_dict[i] for i in gene_dict.keys() if i not in candidates['gene'].tolist()])
    
    p = resample(candidates, df)
    p_dict[pop] = [df['dxy'].median(), candidates['dxy'].median(), df.shape[0], p]
    
    print('p = ', p)
# Out:
# ---- 10FrenchGuianahuman ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12404158673022025
# essential count: 6, nonessential_count: 3
# resampling pool size:  4776
# p =  0.004
#
# ---- 11Alebeer ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12118102037780752
# essential count: 6, nonessential_count: 3
# resampling pool size:  4765
# p =  0.0054
#
# ---- 12WestAfricancocoa ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12128685682902553
# essential count: 6, nonessential_count: 3
# resampling pool size:  4777
# p =  0.0066
#
# ---- 13Africanpalmwine ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1219186268885064
# essential count: 6, nonessential_count: 3
# resampling pool size:  4765
# p =  0.0071
#
# ---- 14CHNIII ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1223175965665236
# essential count: 6, nonessential_count: 3
# resampling pool size:  4780
# p =  0.0096
#
# ---- 15CHNII ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12006948702227672
# essential count: 6, nonessential_count: 3
# resampling pool size:  4779
# p =  0.0107
#
# ---- 16CHNI ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12074391988555078
# essential count: 6, nonessential_count: 3
# resampling pool size:  4781
# p =  0.0106
#
# ---- 17Taiwanese ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12023979835138635
# essential count: 6, nonessential_count: 3
# resampling pool size:  4779
# p =  0.0142
#
# ---- 18FarEastAsia ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12162499716147784
# essential count: 6, nonessential_count: 3
# resampling pool size:  4778
# p =  0.0083
#
# ---- 19Malaysian ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12156822671844132
# essential count: 6, nonessential_count: 3
# resampling pool size:  4778
# p =  0.0079
#
# ---- 1WineEuropean ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12256039081699932
# essential count: 6, nonessential_count: 3
# resampling pool size:  4110
# p =  0.0058
#
# ---- 1WineEuropeansubclade1 ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12255689424364123
# essential count: 6, nonessential_count: 3
# resampling pool size:  4774
# p =  0.0061
#
# ---- 1WineEuropeansubclade2 ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12272634375638668
# essential count: 6, nonessential_count: 3
# resampling pool size:  4776
# p =  0.0078
#
# ---- 1WineEuropeansubclade3 ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1223337795626952
# essential count: 6, nonessential_count: 3
# resampling pool size:  4774
# p =  0.0066
#
# ---- 1WineEuropeansubclade4 ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12256261513289625
# essential count: 6, nonessential_count: 3
# resampling pool size:  4776
# p =  0.0071
#
# ---- 20CHNV ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12244533690316822
# essential count: 6, nonessential_count: 3
# resampling pool size:  4779
# p =  0.0055
#
# ---- 21Ecuadorean ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1218875502008032
# essential count: 6, nonessential_count: 3
# resampling pool size:  4780
# p =  0.0071
#
# ---- 22FarEastRussian ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1216644355198572
# essential count: 6, nonessential_count: 3
# resampling pool size:  4779
# p =  0.0075
#
# ---- 23NorthAmericanoak ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1210913549969344
# essential count: 6, nonessential_count: 3
# resampling pool size:  4780
# p =  0.0068
#
# ---- 24Asianislands ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12225264695144213
# essential count: 6, nonessential_count: 3
# resampling pool size:  4772
# p =  0.0073
#
# ---- 25Sake ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12231479107921045
# essential count: 6, nonessential_count: 3
# resampling pool size:  4774
# p =  0.0062
#
# ---- 26Asianfermentation ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12113327778563827
# essential count: 6, nonessential_count: 3
# resampling pool size:  4769
# p =  0.0081
#
# ---- 2Alpechin ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12280625771058087
# essential count: 6, nonessential_count: 3
# resampling pool size:  4777
# p =  0.0063
#
# ---- 3Brazilianbioethanol ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12218078663861798
# essential count: 6, nonessential_count: 3
# resampling pool size:  4767
# p =  0.0049
#
# ---- 4Mediterraneanoak ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12247087676272225
# essential count: 6, nonessential_count: 3
# resampling pool size:  4772
# p =  0.0059
#
# ---- 5Frenchdairy ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12206883087907185
# essential count: 6, nonessential_count: 3
# resampling pool size:  4762
# p =  0.008
#
# ---- 6Africanbeer ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12262658933749722
# essential count: 6, nonessential_count: 3
# resampling pool size:  4766
# p =  0.0052
#
# ---- 7Mosaicbeer ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1228012579418202
# essential count: 6, nonessential_count: 3
# resampling pool size:  4770
# p =  0.0048
#
# ---- 8Mixedorigin ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12012341894316145
# essential count: 6, nonessential_count: 3
# resampling pool size:  4764
# p =  0.0063
#
# ---- 9Mexicanagave ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.1220110361741263
# essential count: 6, nonessential_count: 3
# resampling pool size:  4774
# p =  0.0078
#
# ---- M1Mosaicregion1 ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12187278344814323
# essential count: 6, nonessential_count: 3
# resampling pool size:  4768
# p =  0.0062
#
# ---- M2Mosaicregion2 ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12252342704149932
# essential count: 6, nonessential_count: 3
# resampling pool size:  4770
# p =  0.0054
#
# ---- M3Mosaicregion3 ----
# missing:  ['CEP3']
# candidate gene median dxy:  0.12177320318533427
# essential count: 6, nonessential_count: 3
# resampling pool size:  4736
# p =  0.0043

# %%
with open('dxy_by_scer_pop_NAspar.csv', 'w') as f:
    w = csv.writer(f, delimiter=',')
    w.writerow(['S. cerevisiae population', 'Genomic median Dxy', 'Candidate genes median Dxy', 'Resampling pool size', 'Resampling p value'])

    for pop in p_dict:
        w.writerow([pop]+p_dict[pop])
