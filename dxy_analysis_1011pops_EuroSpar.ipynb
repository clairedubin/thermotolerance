# %% [markdown]
# **Calculate Dxy p values using a resampling test for S. cerevisiae populations (Peter et al., 2018) and European S. paradoxus (Bergstrom et al., 2014).**

# %%
import pandas as pd
import numpy as np
import csv
from resample import resample_med

# %%
#essential genes - from Winzeler et al., 1999
essential = pd.read_csv('/Users/clairedubin/sacc/external_datasets/essential.csv', header=None)
essential[1] = essential[1].str.strip('\t')
essential_genes = [i.split(' ')[0] for i in essential[1]]

# %%
gene_dict = {'YLR397C':'AFG2',
             'YGR098C':'ESP1',
             'YMR168C':'CEP3',
             'YKR054C': 'DYN1',
             'YHR023W':'MYO1',
             'YDR180W':'SCC2',
             'YPL174C':'NIP100',
             'YCR042C': 'TAF2',
             'YMR016C':'SOK2',
             'YJR135C':'MCM22',
             'YJL025W':'RRN7',
             'YDR443C':'SSN2',
             'YKL134C':'OCT1',
             'YPR164W':'MMS1',}

# %%
#group Scer strains by population

pops = pd.read_csv('/Users/clairedubin/sacc/external_datasets/1011_pops_tableS1.csv', skiprows=3)
pops = pops[['Standardized name', 'Clades']].dropna()
pops['population'] = pops['Clades'].str.replace('[^\w]','')

pop_dict = pops.groupby('population')['Standardized name'].count().to_dict()
pop_dict
# Out:
# <ipython-input-4-c38df5675e67>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   pops['population'] = pops['Clades'].str.replace('[^\w]','')
# {'10FrenchGuianahuman': 31,
#  '11Alebeer': 18,
#  '12WestAfricancocoa': 13,
#  '13Africanpalmwine': 28,
#  '14CHNIII': 2,
#  '15CHNII': 2,
#  '16CHNI': 1,
#  '17Taiwanese': 3,
#  '18FarEastAsia': 9,
#  '19Malaysian': 6,
#  '1WineEuropean': 268,
#  '1WineEuropeansubclade1': 18,
#  '1WineEuropeansubclade2': 13,
#  '1WineEuropeansubclade3': 24,
#  '1WineEuropeansubclade4': 39,
#  '20CHNV': 2,
#  '21Ecuadorean': 10,
#  '22FarEastRussian': 4,
#  '23NorthAmericanoak': 13,
#  '24Asianislands': 11,
#  '25Sake': 47,
#  '26Asianfermentation': 39,
#  '2Alpechin': 17,
#  '3Brazilianbioethanol': 35,
#  '4Mediterraneanoak': 8,
#  '5Frenchdairy': 32,
#  '6Africanbeer': 20,
#  '7Mosaicbeer': 21,
#  '8Mixedorigin': 72,
#  '9Mexicanagave': 7,
#  'M1Mosaicregion1': 17,
#  'M2Mosaicregion2': 20,
#  'M3Mosaicregion3': 113}

# %%
#load raw dxy data

all_dxy = pd.read_csv('/Users/clairedubin/sacc/carly_genes/dxy_1011pops_EuroSpar.csv', header=None)
all_dxy.columns = ['population', 'gene', 'dxy', 'spar_strain_count', 'scer_strain_count']
all_dxy.head()
# Out:
#         population     gene       dxy  spar_strain_count  scer_strain_count
# 0      19Malaysian  YLR457C  0.131458                 10                  6
# 1  M1Mosaicregion1  YLR457C  0.134645                 10                 17
# 2      19Malaysian  YLR129W  0.090490                 10                  6
# 3  M2Mosaicregion2  YLR457C  0.134531                 10                 20
# 4      19Malaysian  YIL093C  0.072704                 10                  6

# %%
#drop any rows where spar_strain_count < 8 or scer_strain count < 75% of the population
all_dxy = all_dxy[all_dxy['spar_strain_count'] >= 8]

# %% [markdown]
# ### Resample Dxy by Scer population

# %%
np.random.seed(777)

p_dict = {}

for pop in pop_dict:
    size = pop_dict[pop]
    
    df = all_dxy[all_dxy['population']==pop]
    df = df[df['scer_strain_count']>= .75*size]
    
    candidates = df[df['gene'].isin(gene_dict.keys())]
    
    print('')
    print('---- {} ----'.format(pop))

    print('missing: ', [gene_dict[i] for i in gene_dict.keys() if i not in candidates['gene'].tolist()])
    
    p = resample_med(candidates, df, 'dxy', essential_genes, direction='greater_than')
    p_dict[pop] = [df['dxy'].median(), candidates['dxy'].median(), df.shape[0], p]
# Out:
# ---- 10FrenchGuianahuman ----
# missing:  []
# candidate gene median dxy: 0.12131835182103609
# essential count: 6; nonessential_count: 8
# resampling pool size: 4570
# p = 0.004
#
# ---- 11Alebeer ----
# missing:  []
# candidate gene median dxy: 0.11847805744303011
# essential count: 6; nonessential_count: 8
# resampling pool size: 4562
# p = 0.004
#
# ---- 12WestAfricancocoa ----
# missing:  []
# candidate gene median dxy: 0.12033658386278165
# essential count: 6; nonessential_count: 8
# resampling pool size: 4569
# p = 0.0032
#
# ---- 13Africanpalmwine ----
# missing:  []
# candidate gene median dxy: 0.12097061883124041
# essential count: 6; nonessential_count: 8
# resampling pool size: 4562
# p = 0.0031
#
# ---- 14CHNIII ----
# missing:  []
# candidate gene median dxy: 0.1206012060674587
# essential count: 6; nonessential_count: 8
# resampling pool size: 4574
# p = 0.0037
#
# ---- 15CHNII ----
# missing:  []
# candidate gene median dxy: 0.11991804427010361
# essential count: 6; nonessential_count: 8
# resampling pool size: 4573
# p = 0.0045
#
# ---- 16CHNI ----
# missing:  []
# candidate gene median dxy: 0.1213899575825903
# essential count: 6; nonessential_count: 8
# resampling pool size: 4575
# p = 0.0037
#
# ---- 17Taiwanese ----
# missing:  []
# candidate gene median dxy: 0.12199911489396084
# essential count: 6; nonessential_count: 8
# resampling pool size: 4566
# p = 0.0026
#
# ---- 18FarEastAsia ----
# missing:  []
# candidate gene median dxy: 0.12014007796906831
# essential count: 6; nonessential_count: 8
# resampling pool size: 4571
# p = 0.0037
#
# ---- 19Malaysian ----
# missing:  []
# candidate gene median dxy: 0.12144517296957005
# essential count: 6; nonessential_count: 8
# resampling pool size: 4569
# p = 0.0036
#
# ---- 1WineEuropean ----
# missing:  []
# candidate gene median dxy: 0.12038731500493854
# essential count: 6; nonessential_count: 8
# resampling pool size: 4555
# p = 0.0047
#
# ---- 1WineEuropeansubclade1 ----
# missing:  []
# candidate gene median dxy: 0.12033227656534831
# essential count: 6; nonessential_count: 8
# resampling pool size: 4571
# p = 0.0054
#
# ---- 1WineEuropeansubclade2 ----
# missing:  []
# candidate gene median dxy: 0.12035380640031801
# essential count: 6; nonessential_count: 8
# resampling pool size: 4573
# p = 0.0043
#
# ---- 1WineEuropeansubclade3 ----
# missing:  []
# candidate gene median dxy: 0.1202027749239853
# essential count: 6; nonessential_count: 8
# resampling pool size: 4572
# p = 0.0047
#
# ---- 1WineEuropeansubclade4 ----
# missing:  []
# candidate gene median dxy: 0.12019830797382865
# essential count: 6; nonessential_count: 8
# resampling pool size: 4566
# p = 0.0037
#
# ---- 20CHNV ----
# missing:  []
# candidate gene median dxy: 0.1211615416793814
# essential count: 6; nonessential_count: 8
# resampling pool size: 4572
# p = 0.003
#
# ---- 21Ecuadorean ----
# missing:  []
# candidate gene median dxy: 0.1208174964428662
# essential count: 6; nonessential_count: 8
# resampling pool size: 4575
# p = 0.0033
#
# ---- 22FarEastRussian ----
# missing:  []
# candidate gene median dxy: 0.12094372822069824
# essential count: 6; nonessential_count: 8
# resampling pool size: 4572
# p = 0.0038
#
# ---- 23NorthAmericanoak ----
# missing:  []
# candidate gene median dxy: 0.12062565507508065
# essential count: 6; nonessential_count: 8
# resampling pool size: 4576
# p = 0.0034
#
# ---- 24Asianislands ----
# missing:  []
# candidate gene median dxy: 0.12094806286456605
# essential count: 6; nonessential_count: 8
# resampling pool size: 4567
# p = 0.0027
#
# ---- 25Sake ----
# missing:  []
# candidate gene median dxy: 0.12106942891945704
# essential count: 6; nonessential_count: 8
# resampling pool size: 4569
# p = 0.0033
#
# ---- 26Asianfermentation ----
# missing:  []
# candidate gene median dxy: 0.12057908969742345
# essential count: 6; nonessential_count: 8
# resampling pool size: 4559
# p = 0.0037
#
# ---- 2Alpechin ----
# missing:  []
# candidate gene median dxy: 0.1208072600479437
# essential count: 6; nonessential_count: 8
# resampling pool size: 4569
# p = 0.0035
#
# ---- 3Brazilianbioethanol ----
# missing:  []
# candidate gene median dxy: 0.1199628794788426
# essential count: 6; nonessential_count: 8
# resampling pool size: 4564
# p = 0.0037
#
# ---- 4Mediterraneanoak ----
# missing:  []
# candidate gene median dxy: 0.12042151162790696
# essential count: 6; nonessential_count: 8
# resampling pool size: 4570
# p = 0.0045
#
# ---- 5Frenchdairy ----
# missing:  []
# candidate gene median dxy: 0.119187282884769
# essential count: 6; nonessential_count: 8
# resampling pool size: 4558
# p = 0.0045
#
# ---- 6Africanbeer ----
# missing:  []
# candidate gene median dxy: 0.11957403269112604
# essential count: 6; nonessential_count: 8
# resampling pool size: 4557
# p = 0.0032
#
# ---- 7Mosaicbeer ----
# missing:  []
# candidate gene median dxy: 0.1207133690415655
# essential count: 6; nonessential_count: 8
# resampling pool size: 4564
# p = 0.0032
#
# ---- 8Mixedorigin ----
# missing:  []
# candidate gene median dxy: 0.11905990672422676
# essential count: 6; nonessential_count: 8
# resampling pool size: 4562
# p = 0.0034
#
# ---- 9Mexicanagave ----
# missing:  []
# candidate gene median dxy: 0.1199652266242133
# essential count: 6; nonessential_count: 8
# resampling pool size: 4571
# p = 0.0038
#
# ---- M1Mosaicregion1 ----
# missing:  []
# candidate gene median dxy: 0.12046883383969065
# essential count: 6; nonessential_count: 8
# resampling pool size: 4567
# p = 0.0044
#
# ---- M2Mosaicregion2 ----
# missing:  []
# candidate gene median dxy: 0.12043678590330305
# essential count: 6; nonessential_count: 8
# resampling pool size: 4566
# p = 0.0034
#
# ---- M3Mosaicregion3 ----
# missing:  []
# candidate gene median dxy: 0.12048909548233866
# essential count: 6; nonessential_count: 8
# resampling pool size: 4539
# p = 0.0027

# %%
with open('dxy_p_vals_by_scer_pop_Eurospar.csv', 'w') as f:
    w = csv.writer(f, delimiter=',')
    w.writerow(['S. cerevisiae population', 'Genomic median Dxy', 'Candidate genes median Dxy', 'Resampling pool size', 'Resampling p value'])

    for pop in p_dict:
        w.writerow([pop]+p_dict[pop])
